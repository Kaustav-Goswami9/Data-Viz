# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('no_encoding_data.csv')

# columns from Q4_1 to Q4_6
Q4_columns = ['Q4_1', 'Q4_2', 'Q4_3', 'Q4_4', 'Q4_5', 'Q4_6']
col_names = ['Company executives', 'Department heads', 'Immediate supervisors',
             'Internal communications', 'Large stakeholders', 'Company policies and regulations']

# create a value_counts dataframe for each column
value_counts = [data[col].value_counts() for col in Q4_columns]

# create a dataframe from the value_counts
df = pd.DataFrame(value_counts).T
df.columns = col_names
df[df.index != '-1']
# Out:
#                        Company executives  Department heads  \
# A significant impact                 2596              2345
# Somewhat of an impact                2023              2314
# Just a slight impact                  834               810
# No impact at all                      344               328
#
#                        Immediate supervisors  Internal communications  \
# A significant impact                    1877                     1090
# Somewhat of an impact                   2352                     2048
# Just a slight impact                    1155                     1593
# No impact at all                         419                     1067
#
#                        Large stakeholders  Company policies and regulations
# A significant impact                 1234                              1971
# Somewhat of an impact                2201                              2106
# Just a slight impact                 1372                              1212
# No impact at all                      985                               514

# %%
data = pd.read_csv('no_encoding_data.csv')

temp = data['Q6'].value_counts()
# replace -1 in index with 'No response'
temp = temp.rename(index={'-1': 'No response'})
temp
# Out:
# Q6
# Only a few     2669
# Some           1568
# A lot           230
# No response      47
# Name: count, dtype: int64

# %%
data = pd.read_csv('no_encoding_data.csv')
q3_columns = ['Q3_1', 'Q3_2', 'Q3_3', 'Q3_4', 'Q3_5', 'Q3_6']

temp = data[data[q3_columns] != '-1']

temp = temp[q3_columns].apply(pd.Series.value_counts).T
temp.to_csv('value_counts.csv')

# %%
data = pd.read_csv('no_encoding_data.csv')
q8_columns = ['Q8_1', 'Q8_2', 'Q8_3', 'Q8_4',
              'Q8_5', 'Q8_6', 'Q8_7', 'Q8_8', 'Q8_9']

temp = data[data[q8_columns] != '-1']

temp = temp[q8_columns].apply(pd.Series.value_counts)
# change the column names
temp.columns = ['company leadership', 'union representatives', 'community council',
                'health and safety committee', 'Internal audit teams', 'grievance committee',
                'internal communications team', 'security team', "company's postal services"]
temp
# Out:
#             company leadership  union representatives  community council  \
# A lot                      948                    228               1075
# Not at all                2185                   1205                392
# Not much                  1093                   2354               1140
# Some                      1563                   2000               3187
#
#             health and safety committee  Internal audit teams  \
# A lot                              1744                   541
# Not at all                          433                   748
# Not much                            977                  1864
# Some                               2648                  2634
#
#             grievance committee  internal communications team  security team  \
# A lot                      1038                           417           1813
# Not at all                  578                          1767            466
# Not much                   1304                          1598            885
# Some                       2890                          2012           2643
#
#             company's postal services
# A lot                            2157
# Not at all                        234
# Not much                          713
# Some                             2695
